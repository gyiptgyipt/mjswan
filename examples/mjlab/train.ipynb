# %%
# !if [ ! -d "mjlab" ]; then git clone -q https://github.com/mujocolab/mjlab.git; fi
# %cd mjlab
# !uv pip install --system -e . -q
# Out:
# /content/mjlab

# %%
# !wandb login
# Out:
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Create a new API key at: https://wandb.ai/authorize?ref=models
# wandb: Store your API key securely and do not share it.
# wandb: Paste your API key and hit enter:
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: ttktjmt (ttktjmt-org) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %%
# !python -m mjlab.scripts.list_envs
# Out:
# +---------------------------------------------------------+
# |             Available Environments in mjlab             |
# +----+----------------------------------------------------+
# | #  | Task ID                                            |
# +----+----------------------------------------------------+
# | 1  | Mjlab-Cartpole-Balance                             |
# | 2  | Mjlab-Cartpole-Swingup                             |
# | 3  | Mjlab-Lift-Cube-Yam                                |
# | 4  | Mjlab-Lift-Cube-Yam-Depth                          |
# | 5  | Mjlab-Lift-Cube-Yam-Rgb                            |
# | 6  | Mjlab-Multi-Cube-Seg-Yam                           |
# | 7  | Mjlab-Tracking-Flat-Unitree-G1                     |
# | 8  | Mjlab-Tracking-Flat-Unitree-G1-No-State-Estimation |
# | 9  | Mjlab-Velocity-Flat-Unitree-G1                     |
# | 10 | Mjlab-Velocity-Flat-Unitree-Go1                    |
# | 11 | Mjlab-Velocity-Rough-Unitree-G1                    |
# ...

# %%
# @title Mjlab-Velocity-Flat-Unitree-Go1
import os

os.environ["WANDB_RUN_ID"] = "vel-flat-go1"
os.environ["WANDB_RESUME"] = "allow"

# !python -m mjlab.scripts.train Mjlab-Velocity-Flat-Unitree-Go1 --agent.max-iterations 1_001 --agent.save-interval 100

# %%
# @title Mjlab-Velocity-Flat-Unitree-G1
import os

os.environ["WANDB_RUN_ID"] = "vel-flat-g1"
os.environ["WANDB_RESUME"] = "allow"

# !python -m mjlab.scripts.train Mjlab-Velocity-Flat-Unitree-G1 --env.scene.num-envs 4096 --agent.max-iterations 30_001 --agent.save-interval 200
